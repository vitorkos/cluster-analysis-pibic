# %% [markdown]
# ### PIBIC - AVALIAÇÕES DAS PROPRIEDADES FÍSICAS DA MASSA E DE PÃES ELABORADOS COM ADIÇÃO DE FARINHAS DE BIOMASSA DE BANANA E DE SOJA
#
# #### O código abaixo trata-se do codigo realizado na linguagem de programação python para realização da analise de clusters da imagem das fatias dos pães elaborados
#
# #### Desenvolvido pelo bolsista de PIBIC Vitor Kauã Oliveira de Souza, do segundo ano de Ciência da Computação da Universidade Estadual do Norte do Paraná, orientado pelo professor Doutor Luís Guilherme Sachs.
#
# ---

# %% [markdown]
# #### Inclusão das bibliotecas necessárias
#
# ##### OBS: O CAMINHO PATH E A VARIAVEL PATH_TO_MODULE ESTÁ EXCLUSIVAMENTE NA MINHA MÁQUINA. NA SUA, VOCE DEVERÁ TER SEU AMBIENTE VIRTUAL PYTHON CONFIGURADO E COM AS BIBLIOTECAS INSTALADAS E NA VARIAVEL, PASSAR O CAMINHO QUE ESTÁ NA SUA MÁQUINA

# %%
import os
os.sys.path
import sys
path_to_module = "../venv/lib/python3.11/site-packages/"
sys.path.append(path_to_module)

# %% [markdown]
# #### Incluindo as bibliotecas baixadas no ambiente virtual

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Código principal

# %%
# Read and prepare image
img = cv2.imread('./../models/aline_models/default-photos/aline_exp_img1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (7, 7), 0)

# Apply adaptive thresholding
mask = cv2.adaptiveThreshold(blurred,
                              255,
                              cv2.ADAPTIVE_THRESH_MEAN_C,
                              cv2.THRESH_BINARY,
                              31,
                              10)

# Plot results

fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax[1].imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2RGB))
plt.tight_layout()

# %%
ax = plt.subplots(1, figsize=(12,5))
ax[1].imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2RGB))
ax[1].axis('off')
plt.tight_layout()

# Save the plotted image
#plt.savefig('./../tests/pao1/pao1_clusters.jpg', bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ##### Cluster counting ad

# %%
image = cv2.imread('./../tests/pao1/pao1_clusters.jpg')
contours, hierarchy = cv2.findContours(image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
out = image.copy()
out = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

for c in contours:
    cv2.polylines(out,[c],True,(255,0,0),1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[40], line 2
#       1 image = cv2.imread('./../tests/pao1/pao1_clusters.jpg')
# ----> 2 contours, hierarchy = cv2.findContours(image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#       3 out = image.copy()
#       4 out = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
#
# error: OpenCV(4.8.1) /io/opencv/modules/imgproc/src/contours.cpp:195: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'
